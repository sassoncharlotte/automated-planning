# %% [markdown]
# ### Parsing of the pddl files

# %%
from pddl import parse_domain, parse_problem

DOMAIN_PATH = 'pddl_files/domain.pddl'
PROBLEM_PATH = 'pddl_files/problem0.pddl'

domain = parse_domain(DOMAIN_PATH)
problem = parse_problem(PROBLEM_PATH)
problem.goal
# Out:
# Predicate(at, pos11)

# %% [markdown]
# ### Creating a graph from pddl files

# %%
from planning_graph.planning_graph import PlanningGraph

planning_graph = PlanningGraph(
    'pddl_files/domain.pddl',
    'pddl_files/problem0.pddl',
    visualize=True
)
graph = planning_graph.create(max_num_of_levels=10)

# %%
for action in graph.act[9]:
    print(action.effect_pos)
# Out:
# {('at', 'pos32')}
# {('at', 'pos43')}
# {('at', 'pos23')}
# {('at', 'pos62')}
# {('at', 'pos51')}
# {('at', 'pos63')}
# {('at', 'pos52')}
# {('at', 'pos43')}
# {('at', 'pos53')}
# {('at', 'pos62')}
# {('at', 'pos61')}
# {('at', 'pos63')}
# {('at', 'pos52')}
# {('at', 'pos12')}
# {('at', 'pos12')}
# {('at', 'pos23')}
# {('at', 'pos11')}
# {('at', 'pos13')}
# {('at', 'pos22')}
# {('at', 'pos31')}
# {('at', 'pos51')}
# {('at', 'pos53')}
# {('at', 'pos62')}
# {('at', 'pos51')}
# {('at', 'pos12')}
# {('at', 'pos32')}
# {('at', 'pos23')}
# {('at', 'pos33')}
# {('at', 'pos22')}
# {('at', 'pos31')}
# {('at', 'pos41')}
# {('at', 'pos32')}
# {('at', 'pos61')}
# {('at', 'pos41')}
# {('at', 'pos52')}
# {('at', 'pos33')}
# {('at', 'pos53')}
# {('at', 'pos33')}
# {('at', 'pos13')}
# {('at', 'pos22')}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {('adjacent', 'pos12', 'pos13')}
# {('adjacent', 'pos13', 'pos12')}
# {('at', 'pos63')}
# {('at', 'pos61')}
# {('adjacent', 'pos51', 'pos41')}
# {('at', 'pos32')}
# {('adjacent', 'pos31', 'pos41')}
# {('adjacent', 'pos43', 'pos33')}
# {('munition',)}
# {('adjacent', 'pos52', 'pos62')}
# {('adjacent', 'pos22', 'pos21')}
# {('adjacent', 'pos32', 'pos33')}
# {('adjacent', 'pos23', 'pos33')}
# {('adjacent', 'pos21', 'pos31')}
# {('adjacent', 'pos42', 'pos32')}
# {('adjacent', 'pos21', 'pos22')}
# {('adjacent', 'pos61', 'pos62')}
# {('adjacent', 'pos52', 'pos51')}
# {('adjacent', 'pos41', 'pos42')}
# {('adjacent', 'pos22', 'pos23')}
# {('adjacent', 'pos61', 'pos51')}
# {('adjacent', 'pos51', 'pos52')}
# {('adjacent', 'pos33', 'pos23')}
# {('at', 'pos22')}
# {('at', 'pos31')}
# {('adjacent', 'pos12', 'pos22')}
# {('adjacent', 'pos11', 'pos21')}
# {('adjacent', 'pos53', 'pos52')}
# {('obstacle', 'pos42')}
# {('adjacent', 'pos33', 'pos43')}
# {('adjacent', 'pos52', 'pos53')}
# {('adjacent', 'pos22', 'pos12')}
# {('adjacent', 'pos53', 'pos43')}
# {('adjacent', 'pos63', 'pos62')}
# {('adjacent', 'pos21', 'pos11')}
# {('adjacent', 'pos43', 'pos53')}
# {('adjacent', 'pos23', 'pos13')}
# {('adjacent', 'pos41', 'pos31')}
# {('at', 'pos33')}
# {('adjacent', 'pos31', 'pos32')}
# {('adjacent', 'pos52', 'pos42')}
# {('adjacent', 'pos51', 'pos61')}
# {('at', 'pos41')}
# {('adjacent', 'pos43', 'pos42')}
# {('at', 'pos62')}
# {('adjacent', 'pos42', 'pos41')}
# {('adjacent', 'pos32', 'pos42')}
# {('adjacent', 'pos53', 'pos63')}
# {('adjacent', 'pos22', 'pos32')}
# {('at', 'pos23')}
# {('adjacent', 'pos33', 'pos32')}
# {('at', 'pos11')}
# {('at', 'pos51')}
# {('adjacent', 'pos12', 'pos11')}
# {('adjacent', 'pos13', 'pos23')}
# {('adjacent', 'pos62', 'pos52')}
# {('at', 'pos52')}
# {('adjacent', 'pos63', 'pos53')}
# {('adjacent', 'pos11', 'pos12')}
# {('at', 'pos43')}
# {('adjacent', 'pos42', 'pos52')}
# {('adjacent', 'pos62', 'pos63')}
# {('adjacent', 'pos41', 'pos51')}
# {('obstacle', 'pos21')}
# {('adjacent', 'pos42', 'pos43')}
# {('adjacent', 'pos23', 'pos22')}
# {('at', 'pos12')}
# {('at', 'pos53')}
# {('adjacent', 'pos32', 'pos22')}
# {('adjacent', 'pos31', 'pos21')}
# {('at', 'pos13')}
# {('adjacent', 'pos32', 'pos31')}
# {('adjacent', 'pos62', 'pos61')}

# %%
for action1, action2 in graph.act_mutexes[1]:
    print(action2.effect_pos)
# Out:
# {('at', 'pos63')}
# {('at', 'pos52')}
# set()
# set()
# set()
# {('at', 'pos62')}
# {('at', 'pos61')}
# {('at', 'pos52')}
# set()
# set()
# set()
# {('at', 'pos62')}
# {('at', 'pos61')}
# {('at', 'pos63')}
# set()
# set()
# set()
# {('at', 'pos62')}
# {('at', 'pos61')}
# {('at', 'pos63')}
# {('at', 'pos52')}
# set()
# set()
# {('munition',)}
# {('at', 'pos61')}
# {('at', 'pos63')}
# {('at', 'pos52')}
# set()
# set()
# {('munition',)}
# {('at', 'pos61')}
# {('at', 'pos63')}
# {('at', 'pos52')}
# set()
# set()
# {('munition',)}
# set()
# set()
# set()
# {('at', 'pos61')}
# {('at', 'pos63')}
# {('at', 'pos52')}

# %%
graph.visualize_png("generated_graph.png")
goal, initial_state = planning_graph.goal, planning_graph.initial_state
print("initial state:", initial_state, "\n")
print("goal:", goal)
# Out:
# initial state: {('adjacent', 'pos12', 'pos13'), ('adjacent', 'pos13', 'pos12'), ('adjacent', 'pos31', 'pos41'), ('adjacent', 'pos43', 'pos33'), ('munition',), ('adjacent', 'pos52', 'pos62'), ('adjacent', 'pos22', 'pos21'), ('adjacent', 'pos51', 'pos41'), ('adjacent', 'pos32', 'pos33'), ('adjacent', 'pos23', 'pos33'), ('adjacent', 'pos21', 'pos31'), ('adjacent', 'pos42', 'pos32'), ('adjacent', 'pos21', 'pos22'), ('adjacent', 'pos61', 'pos62'), ('adjacent', 'pos52', 'pos51'), ('adjacent', 'pos41', 'pos42'), ('adjacent', 'pos22', 'pos23'), ('adjacent', 'pos61', 'pos51'), ('adjacent', 'pos51', 'pos52'), ('adjacent', 'pos33', 'pos23'), ('adjacent', 'pos12', 'pos22'), ('adjacent', 'pos11', 'pos21'), ('adjacent', 'pos53', 'pos52'), ('obstacle', 'pos42'), ('adjacent', 'pos33', 'pos43'), ('adjacent', 'pos52', 'pos53'), ('adjacent', 'pos22', 'pos12'), ('adjacent', 'pos53', 'pos43'), ('adjacent', 'pos63', 'pos62'), ('adjacent', 'pos21', 'pos11'), ('adjacent', 'pos43', 'pos53'), ('adjacent', 'pos23', 'pos13'), ('adjacent', 'pos41', 'pos31'), ('adjacent', 'pos31', 'pos32'), ('adjacent', 'pos52', 'pos42'), ('adjacent', 'pos51', 'pos61'), ('adjacent', 'pos43', 'pos42'), ('at', 'pos62'), ('adjacent', 'pos42', 'pos41'), ('adjacent', 'pos32', 'pos42'), ('adjacent', 'pos53', 'pos63'), ('adjacent', 'pos22', 'pos32'), ('adjacent', 'pos33', 'pos32'), ('adjacent', 'pos12', 'pos11'), ('adjacent', 'pos13', 'pos23'), ('adjacent', 'pos62', 'pos52'), ('adjacent', 'pos63', 'pos53'), ('adjacent', 'pos11', 'pos12'), ('adjacent', 'pos42', 'pos52'), ('adjacent', 'pos62', 'pos63'), ('adjacent', 'pos41', 'pos51'), ('obstacle', 'pos21'), ('adjacent', 'pos42', 'pos43'), ('adjacent', 'pos23', 'pos22'), ('adjacent', 'pos32', 'pos22'), ('adjacent', 'pos31', 'pos21'), ('adjacent', 'pos32', 'pos31'), ('adjacent', 'pos62', 'pos61')}
#
# goal: {('at', 'pos11'), ('at', 'pos13'), ('at', 'pos12')}
