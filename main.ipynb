# %%
from planning_graph.planning_graph import PlanningGraph

planning_graph = PlanningGraph(
    'pddl_files/domain.pddl',
    'pddl_files/problem0.pddl',
    visualize=True
)

graph = planning_graph.create(max_num_of_levels=10)
graph.visualize_png("generated_graph.png")
goal, initial_state = planning_graph.goal, planning_graph.initial_state
print("initial state:", initial_state, "\n")
print("goal:", goal)
# Out:
# initial state {('adjacent', 'pos32', 'pos42'), ('adjacent', 'pos33', 'pos43'), ('adjacent', 'pos21', 'pos31'), ('adjacent', 'pos61', 'pos51'), ('adjacent', 'pos42', 'pos32'), ('adjacent', 'pos43', 'pos53'), ('adjacent', 'pos33', 'pos32'), ('adjacent', 'pos62', 'pos63'), ('adjacent', 'pos52', 'pos53'), ('adjacent', 'pos52', 'pos62'), ('adjacent', 'pos21', 'pos22'), ('adjacent', 'pos43', 'pos33'), ('adjacent', 'pos51', 'pos41'), ('adjacent', 'pos21', 'pos11'), ('adjacent', 'pos31', 'pos21'), ('adjacent', 'pos41', 'pos51'), ('obstacle', 'pos21'), ('adjacent', 'pos13', 'pos23'), ('adjacent', 'pos22', 'pos23'), ('munition',), ('adjacent', 'pos61', 'pos62'), ('adjacent', 'pos62', 'pos52'), ('adjacent', 'pos23', 'pos22'), ('adjacent', 'pos51', 'pos52'), ('adjacent', 'pos41', 'pos31'), ('adjacent', 'pos53', 'pos63'), ('adjacent', 'pos23', 'pos13'), ('adjacent', 'pos32', 'pos31'), ('adjacent', 'pos11', 'pos21'), ('adjacent', 'pos23', 'pos33'), ('adjacent', 'pos43', 'pos42'), ('adjacent', 'pos11', 'pos12'), ('adjacent', 'pos63', 'pos53'), ('adjacent', 'pos63', 'pos62'), ('adjacent', 'pos52', 'pos42'), ('adjacent', 'pos22', 'pos12'), ('adjacent', 'pos53', 'pos52'), ('obstacle', 'pos42'), ('adjacent', 'pos13', 'pos12'), ('adjacent', 'pos22', 'pos32'), ('adjacent', 'pos53', 'pos43'), ('adjacent', 'pos31', 'pos41'), ('adjacent', 'pos32', 'pos22'), ('adjacent', 'pos42', 'pos41'), ('at', 'pos62'), ('adjacent', 'pos32', 'pos33'), ('adjacent', 'pos33', 'pos23'), ('adjacent', 'pos62', 'pos61'), ('adjacent', 'pos12', 'pos22'), ('adjacent', 'pos51', 'pos61'), ('adjacent', 'pos12', 'pos11'), ('adjacent', 'pos42', 'pos52'), ('adjacent', 'pos52', 'pos51'), ('adjacent', 'pos41', 'pos42'), ('adjacent', 'pos22', 'pos21'), ('adjacent', 'pos12', 'pos13'), ('adjacent', 'pos31', 'pos32'), ('adjacent', 'pos42', 'pos43')}
#
# goal {('at', 'pos11'), ('at', 'pos13'), ('at', 'pos12')}
